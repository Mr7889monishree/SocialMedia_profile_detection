# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr7889monishree/SocialMedia_profile_detection/blob/main/ML_MINI_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score,precision_score,recall_score

# %%
df_train = pd.read_csv("/content/insta_train.csv")
df_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
len(df_train)
# Out:
# 576

# %%
df_test=pd.read_csv("/content/insta_test.csv")
df_test
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %% [markdown]
# Performing EDA and Preprocessing

# %%
df_train.head() #this will generate the frst 5 rows of the training dataset
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.27               0                   0.0
# 1            1                  0.00               2                   0.0
# 2            1                  0.10               2                   0.0
# 3            1                  0.00               1                   0.0
# 4            1                  0.00               2                   0.0
#
#    name==username  description length  external URL  private  #posts  \
# 0               0                  53             0        0      32
# 1               0                  44             0        0     286
# 2               0                   0             0        1      13
# 3               0                  82             0        0     679
# 4               0                   0             0        1       6
#
#    #followers  #follows  fake
# 0        1000       955     0
# 1        2740       533     0
# ...

# %%
df_train.tail() #this will genertae the last 5 rows of the training dataset
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
#      name==username  description length  external URL  private  #posts  \
# 571               0                   0             0        0      33
# 572               0                  21             0        0      44
# 573               0                   0             0        0       4
# 574               0                  11             0        0       0
# 575               0                   0             0        0       2
#
#      #followers  #follows  fake
# 571         166       596     1
# ...

# %%
df_test.head() #same as training we have for testing
# Out:
#    profile pic  nums/length username  fullname words  nums/length fullname  \
# 0            1                  0.33               1                  0.33
# 1            1                  0.00               5                  0.00
# 2            1                  0.00               2                  0.00
# 3            1                  0.00               1                  0.00
# 4            1                  0.50               1                  0.00
#
#    name==username  description length  external URL  private  #posts  \
# 0               1                  30             0        1      35
# 1               0                  64             0        1       3
# 2               0                  82             0        1     319
# 3               0                 143             0        1     273
# 4               0                  76             0        1       6
#
#    #followers  #follows  fake
# 0         488       604     0
# 1          35         6     0
# ...

# %%
df_test.tail()
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 115            1                  0.29               1                   0.0
# 116            1                  0.40               1                   0.0
# 117            1                  0.00               2                   0.0
# 118            0                  0.17               1                   0.0
# 119            1                  0.44               1                   0.0
#
#      name==username  description length  external URL  private  #posts  \
# 115               0                   0             0        0      13
# 116               0                   0             0        0       4
# 117               0                   0             0        0       3
# 118               0                   0             0        0       1
# 119               0                   0             0        0       3
#
#      #followers  #follows  fake
# 115         114       811     1
# ...

# %%
df_train.info() #this generates the general info about our training dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           576 non-null    int64
#  1   nums/length username  576 non-null    float64
#  2   fullname words        576 non-null    int64
#  3   nums/length fullname  576 non-null    float64
#  4   name==username        576 non-null    int64
#  5   description length    576 non-null    int64
#  6   external URL          576 non-null    int64
#  7   private               576 non-null    int64
#  8   #posts                576 non-null    int64
#  9   #followers            576 non-null    int64
#  10  #follows              576 non-null    int64
#  11  fake                  576 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 54.1 KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   profile pic           120 non-null    int64
#  1   nums/length username  120 non-null    float64
#  2   fullname words        120 non-null    int64
#  3   nums/length fullname  120 non-null    float64
#  4   name==username        120 non-null    int64
#  5   description length    120 non-null    int64
#  6   external URL          120 non-null    int64
#  7   private               120 non-null    int64
#  8   #posts                120 non-null    int64
#  9   #followers            120 non-null    int64
#  10  #follows              120 non-null    int64
#  11  fake                  120 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 11.4 KB

# %%
df_train.describe() #this gives the entire datasets mean sd min and max value according to the percentile
# Out:
#        profile pic  nums/length username  fullname words  \
# count   576.000000            576.000000      576.000000
# mean      0.701389              0.163837        1.460069
# std       0.458047              0.214096        1.052601
# min       0.000000              0.000000        0.000000
# 25%       0.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.310000        2.000000
# max       1.000000              0.920000       12.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            576.000000      576.000000          576.000000    576.000000
# mean               0.036094        0.034722           22.623264      0.116319
# std                0.125121        0.183234           37.702987      0.320886
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
df_test.describe() #same as training for testing and these are some basic steps to be performed to before data standaradizing
# Out:
#        profile pic  nums/length username  fullname words  \
# count   120.000000            120.000000      120.000000
# mean      0.758333              0.179917        1.550000
# std       0.429888              0.241492        1.187116
# min       0.000000              0.000000        0.000000
# 25%       1.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.330000        2.000000
# max       1.000000              0.890000        9.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            120.000000      120.000000          120.000000    120.000000
# mean               0.071333        0.041667           27.200000      0.100000
# std                0.209429        0.200664           42.588632      0.301258
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
df_train.isnull().sum() #it should give the count of the null values if its 0 no issue will be there
# Out:
# profile pic             0
# nums/length username    0
# fullname words          0
# nums/length fullname    0
# name==username          0
# description length      0
# external URL            0
# private                 0
# #posts                  0
# #followers              0
# #follows                0
# fake                    0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# profile pic             0
# nums/length username    0
# fullname words          0
# nums/length fullname    0
# name==username          0
# description length      0
# external URL            0
# private                 0
# #posts                  0
# #followers              0
# #follows                0
# fake                    0
# dtype: int64

# %%
df_train.shape
# Out:
# (576, 12)

# %%
df_test.shape
# Out:
# (120, 12)

# %%
df_train['fake'].value_counts()
# Out:
# fake
# 0    288
# 1    288
# Name: count, dtype: int64

# %%
df_test['fake'].value_counts()
# Out:
# fake
# 0    60
# 1    60
# Name: count, dtype: int64

# %%
df_train.groupby('fake').mean()
# Out:
#       profile pic  nums/length username  fullname words  nums/length fullname  \
# fake
# 0        0.993056              0.038125        1.774306              0.005243
# 1        0.409722              0.289549        1.145833              0.066944
#
#       name==username  description length  external URL   private      #posts  \
# fake
# 0           0.003472           39.982639      0.232639  0.395833  206.045139
# 1           0.065972            5.263889      0.000000  0.368056    8.934028
#
#          #followers    #follows
# fake
# 0     170503.885417  714.597222
# 1        110.586806  302.166667

# %%
df_test.groupby('fake').mean()
# Out:
#       profile pic  nums/length username  fullname words  nums/length fullname  \
# fake
# 0        1.000000              0.059500        1.916667              0.010500
# 1        0.516667              0.300333        1.183333              0.132167
#
#       name==username  description length  external URL   private      #posts  \
# fake
# 0           0.016667                51.0           0.2  0.616667  158.916667
# 1           0.066667                 3.4           0.0  0.000000    6.816667
#
#         #followers    #follows
# fake
# 0     98893.033333  704.600000
# 1       296.400000  853.933333

# %%
#separating data and labels , here label is the output which is 'fake' column
x_train = df_train.drop(columns='fake',axis=1)
x_train
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
x_test=df_test.drop(columns='fake',axis=1)
x_test
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
y_train=df_train['fake']
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 571    1
# 572    1
# 573    1
# 574    1
# 575    1
# Name: fake, Length: 576, dtype: int64

# %%
y_test=df_test['fake']
y_test
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 115    1
# 116    1
# 117    1
# 118    1
# 119    1
# Name: fake, Length: 120, dtype: int64

# %% [markdown]
# MODEL EVALUATION

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
scaler_x = StandardScaler()
X_train = scaler_x.fit_transform(x_train)
X_test=scaler_x.transform(x_test)

# %%
x_train.shape
# Out:
# (576, 11)

# %%
x_test.shape
# Out:
# (120, 11)

# %%
y_train.shape
# Out:
# (576,)

# %%
y_test.shape
# Out:
# (120,)

# %%
# !pip install joblib

# %%
import joblib #this will save the model parameters in the file that we dont need to to retrain it again its a python library

svm_model=SVC()
svm_model.fit(X_train,y_train)

joblib.dump(svm_model, 'svm_model.pkl')
# Out:
# ['svm_model.pkl']

# %%
y_pred = svm_model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8833333333333333

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[56,  4],
#        [10, 50]])

# %%
precision=precision_score(y_test,y_pred,average="binary")
precision
# Out:
# 0.9259259259259259

# %%
recall=recall_score(y_test,y_pred,average="binary")
recall
# Out:
# 0.8333333333333334

# %% [markdown]
# PREDICTIVE SYSTEM

# %%
input_data=(0,0.12,1,0.0,0,0,0,1,0,31,213)

#converting our given data into the array
input_data_as_numpy_array = np.asarray(input_data)


#reshaping in the way it goes through all the column in the input data given  inorder to match the expected output from the input data values given
input_data_reshape=input_data_as_numpy_array.reshape(1,-1)

#standardizing the values of the input data given from the training or testing data set for prediction
std_data = scaler_x.transform(input_data_reshape)

print("Standardized Data:",std_data)

#making the prediction on the model of svm that is standardized in the previous step
prediction=svm_model.predict(std_data)

print("Prediction is Given as:",prediction)

#Checking if the given prediction value is fake profile or true profile

if(prediction[0]==0):
  print("This is a True profile!")
else:
  print("This is a Fake Profile")
# Out:
# Standardized Data: [[-1.53259166 -0.20493143 -0.43745874 -0.28872256 -0.18966081 -0.60056058
#   -0.36280938  1.27207776 -0.26759651 -0.0937763  -0.32205308]]
# Prediction is Given as: [1]
# This is a Fake Profile
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# streamlit is the python framework created for data science and AI/ML engineers to build an their project into an interactive app

# %%
# !pip install streamlit

# %% [markdown]
# THIS WILL CREATE THE PYTHON FILE FOR US TO WRITE THE CODE

# %%
# !pip install scikit-learn
# !pip install opencv-python
# !pip install pytesseract

# %%
# %%writefile app.py
# Out:
# Overwriting app.py

# %%
import streamlit as st
import cv2
import pytesseract
import joblib
import numpy as np

# Load your trained SVM model
model = joblib.load('svm_model.pkl')  # Adjust the path as needed

# Function to extract features from the uploaded image
def extract_features_from_image(image):
    # Convert image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use OCR to extract text
    text = pytesseract.image_to_string(gray)

    # Example logic for extracting the required features:
    profile_pic_exists = 1  # Assume profile pic exists (adjust logic to detect it)
    username_length = len(extract_username(text))
    fullname_words = len(extract_fullname(text).split())
    fullname_length = len(extract_fullname(text))
    name_equals_username = 1 if extract_username(text) == extract_fullname(text) else 0
    description_length = len(extract_description(text))
    external_url_exists = 1 if "http" in text else 0
    is_private = 1 if "Private" in text else 0
    num_posts = extract_num_posts(text)
    num_followers = extract_num_followers(text)
    num_follows = extract_num_follows(text)

    # Combine features into a numpy array for prediction
    features = np.array([[profile_pic_exists, username_length, fullname_words, fullname_length,
                          name_equals_username, description_length, external_url_exists,
                          is_private, num_posts, num_followers, num_follows]])

    return features

def extract_username(text):
    # Implement logic to extract the username from the text
    return "sample_username"  # Replace with actual extraction logic

def extract_fullname(text):
    # Implement logic to extract the full name from the text
    return "Sample Fullname"  # Replace with actual extraction logic

def extract_description(text):
    # Implement logic to extract the description from the text
    return "Sample description"  # Replace with actual extraction logic

def extract_num_posts(text):
    # Implement logic to extract the number of posts from the text
    return 10  # Replace with actual extraction logic

def extract_num_followers(text):
    # Implement logic to extract the number of followers from the text
    return 100  # Replace with actual extraction logic

def extract_num_follows(text):
    # Implement logic to extract the number of follows from the text
    return 50  # Replace with actual extraction logic

st.title("Fake Profile Detection")

uploaded_file = st.file_uploader("Upload a screenshot of the profile", type="jpg")

if uploaded_file is not None:
    # Read the image
    file_bytes = np.asarray(bytearray(uploaded_file.read()), dtype=np.uint8)
    image = cv2.imdecode(file_bytes, 1)

    # Display the uploaded image
    st.image(image, caption='Uploaded Screenshot', use_column_width=True)

    # Extract features
    features = extract_features_from_image(image)

    # Predict using SVM model
    prediction = model.predict(features)

    # Display the result
    if prediction[0] == 1:
        st.success("This profile is likely FAKE.")
    else:
        st.success("This profile is likely GENUINE.")
# Out:
# 2024-08-21 14:14:48.767
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]

# %% [markdown]
# localtunnel: This is a tool that creates a public URL to access your local server. Its useful for exposing local services to the internet.
#
# npx:npx is a tool that comes with npm (Node Package Manager) for running commands from packages without installing them globally.
